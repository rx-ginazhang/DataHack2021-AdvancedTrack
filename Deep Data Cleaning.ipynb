# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/DataHacks2021/
# Out:
# /content/drive/MyDrive/DataHacks2021

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv("3_combined.csv", index_col=0, dtype={0:"str"})

# %%
df
# Out:
#             AAA10Y  ASEANTOT  BAA10Y  ...  WLEMUINDXD  SOFR  SOFRVOL
# 2000-01-03    1.17       NaN    1.69  ...       56.28   NaN      NaN
# 2000-01-04    1.20       NaN    1.72  ...      253.20   NaN      NaN
# 2000-01-05    1.16       NaN    1.67  ...       28.13   NaN      NaN
# 2000-01-06    1.15       NaN    1.67  ...       25.59   NaN      NaN
# 2000-01-07    1.17       NaN    1.70  ...       27.59   NaN      NaN
# ...            ...       ...     ...  ...         ...   ...      ...
# 2021-02-08    1.42       NaN    2.14  ...         NaN  0.02    920.0
# 2021-02-09    1.42       NaN    2.15  ...         NaN  0.05    901.0
# 2021-02-10    1.43       NaN    2.16  ...         NaN  0.06    884.0
# 2021-02-11     NaN       NaN     NaN  ...         NaN  0.06    891.0
# 2021-02-12     NaN       NaN     NaN  ...         NaN   NaN      NaN
#
# [5510 rows x 70 columns]

# %%
2011-2-14 2017-12-29
# Out:
#   File "<ipython-input-6-8fa2f2d8dc17>", line 1
#     2011-2-14 2017-12-29
#                  ^
# SyntaxError: invalid syntax

# %%
col_missing = df.loc["2011/2/14":"2017/12/29"].isnull().mean()
col_missing
# Out:
# AAA10Y                0.041534
# ASEANTOT              0.000000
# BAA10Y                0.041534
# BUSAPPWNSAUS          0.000000
# BUSAPPWNSAUSYY        0.003195
# CBUSAPPWNSAUS         0.000000
# CBUSAPPWNSAUSYY       0.003195
# CUUR0000SA0R          0.000000
# DEXCHUS               0.039617
# DEXUSEU               0.039617
# DEXUSUK               0.039617
# DFII10                0.040895
# DFII20                0.040895
# DFII30                0.040895
# DFII5                 0.040895
# DFII7                 0.040895
# DLTIIT                0.040895
# DPCREDIT              0.000000
# DPRIME                0.036422
# EECTOT                0.000000
# EFFR                  0.037061
# EFFRVOL               0.704153
# FRGSHPUSM649NCIS      0.000000
# GVIPT50002S           0.000000
# GVIPT50030S           0.000000
# GVIPT51000S           0.000000
# GVIPT51100S           0.000000
# GVIPT51110S           0.000000
# GVIPT51120S           0.000000
# GVIPT51200S           0.000000
# ...

# %%
df = df.loc["2011/2/14":"2017/12/29"].drop(columns=["EFFRVOL", "OBFR", "OBFRVOL"])

# %%
df.to_csv("4_combined.csv")
