# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/DataHacks2021/
# Out:
# /content/drive/MyDrive/DataHacks2021

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("5_fill_missing_value.csv", index_col=0)

# %%
df = df.pct_change()
normalized_df=(df-df.min())/(df.max()-df.min())
normalized_df
# Out:
#               AAA10Y  ASEANTOT    BAA10Y  ...  TSIFRGHT    UNRATE  WLEMUINDXD
# 2011/2/14        NaN       NaN       NaN  ...       NaN       NaN         NaN
# 2011/2/15   0.777258  0.599768  0.433083  ...   0.53188  0.668317    0.010803
# 2011/2/16   0.486726  0.599768  0.433083  ...   0.53188  0.668317    0.028318
# 2011/2/17   0.626710  0.599768  0.582008  ...   0.53188  0.668317    0.004487
# 2011/2/18   0.578382  0.599768  0.531203  ...   0.53188  0.668317    0.011915
# ...              ...       ...       ...  ...       ...       ...         ...
# 2017/12/25  0.486726  0.599768  0.433083  ...   0.53188  0.668317    0.040308
# 2017/12/26  0.414771  0.599768  0.362918  ...   0.53188  0.668317    0.028880
# 2017/12/27  0.414093  0.599768  0.291966  ...   0.53188  0.668317    0.004661
# 2017/12/28  0.486726  0.599768  0.433083  ...   0.53188  0.668317    0.013025
# 2017/12/29  0.486726  0.599768  0.504443  ...   0.53188  0.668317    0.025919
#
# [1795 rows x 65 columns]

# %%
pearson_fill = {key: [] for key in normalized_df.columns[2:]}
for i in range(7):
    lst = []
    for col in data5.columns[2:]: 
        if col == 'SP500': 
            continue
        corr, _ = pearsonr(data5['SP500'][1+i:], data5[col][:-(1+i)])
        pearson_fill[col].append(corr)

pearson_fill
